# %% [markdown]
# Name: Rishabh Patil
#
# SAP ID: 60009200056
#
# Batch: D-12

# %%
# !sudo apt update
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

# %%
# !pip install pytesseract -qU

# %%
import cv2
from google.colab.patches import cv2_imshow
from skimage import io
import pytesseract

# %%
img1 = cv2.cvtColor(io.imread('https://jeroen.github.io/images/testocr.png'), cv2.COLOR_BGR2RGB)
cv2_imshow(img1)

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img1, config=custom_config))
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
# This is a lot of 12 point text to test the
# ocr code and see if it works on all types
# of file format.
#
# The quick brown dog jumped over the
# lazy fox. The quick brown dog jumped
# over the lazy fox. The quick brown dog
# jumped over the lazy fox. The quick
# brown dog jumped over the lazy fox.

# %%
img2 = cv2.cvtColor(io.imread('https://b2633864.smushcdn.com/2633864/wp-content/uploads/2017/06/example_01.png'), cv2.COLOR_BGR2RGB)
cv2_imshow(img2)

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img2, config=custom_config))
# Out:
# <PIL.Image.Image image mode=RGB size=500x250>
# Noisyimage
# to test
# Tesseract OCR

# %%
img3 = cv2.cvtColor(io.imread('https://upload.wikimedia.org/wikipedia/commons/0/06/FrenchNumberPlates.jpg'), cv2.COLOR_BGR2RGB)
cv2_imshow(img3)

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img3, config=custom_config))
# Out:
# <PIL.Image.Image image mode=RGB size=413x454>
# ae

# %%
img4 = cv2.cvtColor(io.imread('https://i.stack.imgur.com/PAgNc.png'), cv2.COLOR_BGR2RGB)
cv2_imshow(img4)

# Adding custom options
custom_config = r'--oem 3 --psm 6'
print(pytesseract.image_to_string(img4, config=custom_config))
# Out:
# <PIL.Image.Image image mode=RGB size=898x562>
# oP»
# ee
